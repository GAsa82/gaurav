# %%
import bs4

# %%
import requests

# %%
url = "https://books.toscrape.com/"

# %%
data = requests.get (url)

# %%
soup = bs4.BeautifulSoup(data.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
 # Find all books
books = soup.find_all('article', class_='product_pod')

# Access the first book as an example
book = books[12]

# Get the title
title = book.h3.a['title']
print(title)
# Out:
# Set Me Free

# %%
for para in soup.find_all('p'):
    print(para.text)
# Out:
# Â£51.77
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£53.74
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£50.10
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£47.82
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£54.23
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£22.65
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£33.34
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£17.93
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£22.60
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£52.15
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£13.99
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£20.66
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£17.46
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£52.29
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£35.02
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£57.25
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£23.88
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£37.59
#
#
#
#         In stock
#
#
#
#
#
#
#
#
#
# Â£51.33
#
#
#
#         In stock
#
#
#
#
#
# ...

# %%
base_url = "https://books.toscrape.com/"

# %%
from urllib.parse import urljoin

for a_tag in soup.find_all('a'):
    href = a_tag.get('href')
    if href:
        full_link = urljoin(base_url, href)
        print(full_link)
# Out:
# https://books.toscrape.com/index.html
# https://books.toscrape.com/index.html
# https://books.toscrape.com/catalogue/category/books_1/index.html
# https://books.toscrape.com/catalogue/category/books/travel_2/index.html
# https://books.toscrape.com/catalogue/category/books/mystery_3/index.html
# https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html
# https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html
# https://books.toscrape.com/catalogue/category/books/classics_6/index.html
# https://books.toscrape.com/catalogue/category/books/philosophy_7/index.html
# https://books.toscrape.com/catalogue/category/books/romance_8/index.html
# https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html
# https://books.toscrape.com/catalogue/category/books/fiction_10/index.html
# https://books.toscrape.com/catalogue/category/books/childrens_11/index.html
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://books.toscrape.com/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

books = soup.find_all('article', class_='product_pod')
book = books[3]

price = book.select_one('.price_color').text
print(price)
# Out:
# Â£47.82

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

url = "http://books.toscrape.com/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

books = soup.select('article.product_pod')
base_url = "http://books.toscrape.com/"

for book in books:
    title = book.h3.a['title']
    link = urljoin(base_url, book.h3.a['href'])
    price = book.select_one('.price_color').text
    rating = book.p['class'][1]
    availability = book.select_one('.availability').text.strip()

    print({
        'Title': title,
        'Link': link,
        'Price': price,
        'Rating': rating,
        'Availability': availability
    })
# Out:
# {'Title': 'A Light in the Attic', 'Link': 'http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html', 'Price': 'Â£51.77', 'Rating': 'Three', 'Availability': 'In stock'}
# {'Title': 'Tipping the Velvet', 'Link': 'http://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html', 'Price': 'Â£53.74', 'Rating': 'One', 'Availability': 'In stock'}
# {'Title': 'Soumission', 'Link': 'http://books.toscrape.com/catalogue/soumission_998/index.html', 'Price': 'Â£50.10', 'Rating': 'One', 'Availability': 'In stock'}
# {'Title': 'Sharp Objects', 'Link': 'http://books.toscrape.com/catalogue/sharp-objects_997/index.html', 'Price': 'Â£47.82', 'Rating': 'Four', 'Availability': 'In stock'}
# {'Title': 'Sapiens: A Brief History of Humankind', 'Link': 'http://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html', 'Price': 'Â£54.23', 'Rating': 'Five', 'Availability': 'In stock'}
# ...

# %%
import csv

with open('books_data.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Title', 'Link', 'Price', 'Rating', 'Availability'])
    for book in books:
        title = book.h3.a['title']
        link = urljoin(base_url, book.h3.a['href'])
        price = book.select_one('.price_color').text
        rating = book.p['class'][1]
        availability = book.select_one('.availability').text.strip()

        writer.writerow([title, link, price, rating, availability])
